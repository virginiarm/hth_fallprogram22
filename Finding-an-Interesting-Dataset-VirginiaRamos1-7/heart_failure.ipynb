# %%
import pandas

pandas.options.display.max_columns = None
pandas.options.display.max_rows = None

heart_data = pandas.read_csv("heart_failure_clinical_records_dataset.csv")
heart_data
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.000        0                       582         0                 20
# 1    55.000        0                      7861         0                 38
# 2    65.000        0                       146         0                 20
# 3    50.000        1                       111         0                 20
# 4    65.000        1                       160         1                 20
# 5    90.000        1                        47         0                 40
# 6    75.000        1                       246         0                 15
# 7    60.000        1                       315         1                 60
# 8    65.000        0                       157         0                 65
# 9    80.000        1                       123         0                 35
# 10   75.000        1                        81         0                 38
# ...

# %%
#Q1 What is the average of participants ejection_fraction score?
avg_ejection_fraction = heart_data['ejection_fraction'].mean()
avg_ejection_fraction
# Out:
# 38.08361204013378

# %%
#what is the number of participants who have a ejection fraction that is lower than 40?
# Step 5(e): How many passengers were 60 or older?
ejection_fraction = heart_data[ (heart_data['ejection_fraction']<=40)]
ejection_fraction
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.000        0                       582         0                 20
# 1    55.000        0                      7861         0                 38
# 2    65.000        0                       146         0                 20
# 3    50.000        1                       111         0                 20
# 4    65.000        1                       160         1                 20
# 5    90.000        1                        47         0                 40
# 6    75.000        1                       246         0                 15
# 9    80.000        1                       123         0                 35
# 10   75.000        1                        81         0                 38
# 11   62.000        0                       231         0                 25
# 12   45.000        1                       981         0                 30
# ...

# %%
#Q2How many of the participants are between the ages of 60 and 80?5
senior_adults = heart_data[ (heart_data['age']>=60) & (heart_data['age']<=80)]
senior_adults
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.000        0                       582         0                 20
# 2    65.000        0                       146         0                 20
# 4    65.000        1                       160         1                 20
# 6    75.000        1                       246         0                 15
# 7    60.000        1                       315         1                 60
# 8    65.000        0                       157         0                 65
# 9    80.000        1                       123         0                 35
# 10   75.000        1                        81         0                 38
# 11   62.000        0                       231         0                 25
# 18   70.000        1                       125         0                 25
# 20   65.000        1                        52         0                 25
# ...

# %%
#Q3 What is the average of participants creatine_phosphokinase score?
avg_creatine_phosphokinase = heart_data['creatinine_phosphokinase'].mean()
avg_creatine_phosphokinase
# Out:
# 581.8394648829432

# %%
#Q4: what are the missing values under diabetes?
missing_values =heart_data['diabetes'].isnull().sum
missing_values
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# ...

# %%
missing_values =heart_data(['diabetes'].isnull().sum )df.mean()
missing_values
# Out:
#   Cell In [38], line 1
#     missing_values =heart_data(['diabetes'].isnull().sum )df.mean()
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#3Question: what are the missing values under diabetes?
missing_values =heart_data['diabetes'].isnull().sum
missing_values
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# ...

# %%
#Q5 What is the average age ?
avg_age = heart_data['age'].mean()
avg_age
# Out:
# 60.83389297658862
